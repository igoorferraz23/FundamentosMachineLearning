# %% [markdown]
# ## Conceitos e Técnicas

# %% [markdown]
# São conceitos e técnicas utilizadas para dar apoio ao aprendizado de maquina, buscando uma melhor performance, avaliar melhor os modelos, melhoras as features entre outros.
#
# ---

# %% [markdown]
# ### Validação cruzada

# %%
pass

# %% [markdown]
# ### Feature scaling

# %%
pass

# %% [markdown]
# ### Ensemble avançado

# %%
pass

# %% [markdown]
# ### Hyperparameter tuning

# %%
pass

# %% [markdown]
# ### Interpretabilidade de modelos

# %% [markdown]
# #### SHAP

# %%
pass

# %% [markdown]
# #### LIME

# %%
pass

# %% [markdown]
# ### Deploy de modelos

# %%
pass
